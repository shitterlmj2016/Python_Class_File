# %%
# standard
import numpy as np
import pandas as pd
from numpy.random import randn

# stats
from scipy import stats

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tips)

# %%
sns.lmplot('total_bill','tip',tips,
           scatter_kws={'marker':'o','color':'indianred'},
           line_kws={'linewidth':1, 'color':'blue'})

# %%
sns.lmplot('total_bill','tip',tips,order=4,
           scatter_kws={'marker':'o','color':'indianred'},
           line_kws={'linewidth':1, 'color':'blue'})

# %%
sns.lmplot('total_bill','tip',tips,fit_reg=False)

# %%
tips['tip_pect']=100*(tips['tip']/tips['total_bill'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot('size','tip_pect',tips)

# %%
url = 'https://en.wikipedia.org/wiki/Jitter'

# %%
sns.lmplot('size','tip_pect',tips,x_jitter=.1)

# %%
sns.lmplot('size','tip_pect',tips,x_estimator=np.mean)

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='sex',markers=['x','o'])

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='day')

# %%
url = 'https://en.wikipedia.org/wiki/Local_regression'
sns.lmplot('total_bill','tip_pect',tips,lowess=True,line_kws={'color':'black'})

# %%
sns.regplot('total_bill','tip_pect',tips)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)
sns.regplot('total_bill','tip_pect',tips,ax=axis1)
sns.violinplot(tips['tip_pect'],tips['size'],color='Reds_r',ax=axis2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d62884e02757> in <module>()
#       1 fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)
#       2 sns.regplot('total_bill','tip_pect',tips,ax=axis1)
# ----> 3 sns.violinplot(tips['tip_pect'],tips['size'],color='Reds_r',ax=axis2)
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/seaborn/categorical.pyc in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2345                              bw, cut, scale, scale_hue, gridsize,
#    2346                              width, inner, split, orient, linewidth,
# -> 2347                              color, palette, saturation)
#    2348
#    2349     if ax is None:
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, orient, linewidth, color, palette, saturation)
#     540
#     541         self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 542         self.establish_colors(color, palette, saturation)
#     543         self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#     544
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/seaborn/categorical.pyc in establish_colors(self, color, palette, saturation)
#     297         # Desaturate a bit because these are patches
#     298         if saturation < 1:
# --> 299             colors = color_palette(colors, desat=saturation)
#     300
#     301         # Conver the colors to a common representations
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/seaborn/palettes.pyc in color_palette(palette, n_colors, desat)
#     181
#     182     if desat is not None:
# --> 183         palette = [desaturate(c, desat) for c in palette]
#     184
#     185     # Always return as many colors as we asked for
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/seaborn/utils.pyc in desaturate(color, prop)
#      99
#     100     # Get rgb tuple rep
# --> 101     rgb = mplcol.colorConverter.to_rgb(color)
#     102
#     103     # Convert to hls
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgb(arg)
#     309         if *arg* is *RGBA*, the *A* will simply be discarded.
#     310         """
# --> 311         return to_rgb(arg)
#     312
#     313     @staticmethod
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgb(c)
#     244     """Convert `c` to an RGB color, silently dropping the alpha channel.
#     245     """
# --> 246     return to_rgba(c)[:3]
#     247
#     248
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(c, alpha)
#     141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 143         rgba = _to_rgba_no_colorcycle(c, alpha)
#     144         try:
#     145             _colors_full_map.cache[c, alpha] = rgba
#
# /Users/kolobj/anaconda/envs/cmu2_7/lib/python2.7/site-packages/matplotlib/colors.pyc in _to_rgba_no_colorcycle(c, alpha)
#     185         except ValueError:
#     186             pass
# --> 187         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     188     # tuple color.
#     189     c = np.array(c)
#
# ValueError: Invalid RGBA argument: 'Reds_r'
